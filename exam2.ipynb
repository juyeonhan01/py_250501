# %%
import os
print(os.getcwd())
#현재 디렉토리를 알려주는 함수
# Out:
# c:\Work.juyeon

# %%
os.chdir()
#디렉토리를 이동할 수 있게 해주는 함수
#한국어 인식이 안되기 때문에 영어로 적기

# %%
os.listdir("C:\Work.juyeon")
#입력한 경로의 파일과 폴더 목록을 리스트로 반환하는 함수

for i in os.listdir("C:\Work.juyeon")
print(i)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# <>:4: SyntaxWarning: invalid escape sequence '\W'
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# <>:4: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\admin\AppData\Local\Temp\ipykernel_2268\3934644047.py:1: SyntaxWarning: invalid escape sequence '\W'
#   os.listdir("C:\Work.juyeon")
# C:\Users\admin\AppData\Local\Temp\ipykernel_2268\3934644047.py:4: SyntaxWarning: invalid escape sequence '\W'
#   for i in os.listdir("C:\Work.juyeon")
#   Cell In[3], line 4
#     for i in os.listdir("C:\Work.juyeon")
#                                          ^
# SyntaxError: expected ':'

# %%
print(os.path.exists("c:\work.juyeon\py_test1"))
print(os.path.exists("c:\work.juyeon\py_tes2"))
# 특정 폴더가 존재하는지 하지 않는지 확인해주는 함수
# Out:
# True
# False
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\admin\AppData\Local\Temp\ipykernel_2268\3320882195.py:1: SyntaxWarning: invalid escape sequence '\w'
#   print(os.path.exists("c:\work.juyeon\py_test1"))
# C:\Users\admin\AppData\Local\Temp\ipykernel_2268\3320882195.py:2: SyntaxWarning: invalid escape sequence '\w'
#   print(os.path.exists("c:\work.juyeon\py_tes2"))

# %%
#폴더를 만들어주는 함수
os.mkdir("py_test3")
#새로운 폴더와 그 하위 폴더까지 만들어주는 함수
os.makedirs("C:\Work.juyeon\py_test3\py_test3_1")
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\W'
# <>:4: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\admin\AppData\Local\Temp\ipykernel_2268\777530105.py:4: SyntaxWarning: invalid escape sequence '\W'
#   os.makedirs("C:\Work.juyeon\py_test3\py_test3_1")

# %%
#폴더를 삭제하는 함수
#os.rmdir("C:\Work.juyeon\py_test2")

#여러개의 폴더를 삭제해주는 함수
os.removedirs("C:\Work.juyeon\py_test3\py_test3_1")
#rmdir(), removedirs() 두 함수를 쓸 땐 모두 폴더가 비어있어야함
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\W'
# <>:5: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\admin\AppData\Local\Temp\ipykernel_2268\4212690928.py:5: SyntaxWarning: invalid escape sequence '\W'
#   os.removedirs("C:\Work.juyeon\py_test3\py_test3_1")
