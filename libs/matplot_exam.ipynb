# %%
#matplotlib => 데이터를 그래프로 표현할 수 있게 해주는 파이썬 라이브러리
#figure => 큰 도화지
#subplots => 도화지 위에 나눠진 작은 칸들

# %%
import matplotlib.pyplot as plt
#기본 스타일 적용
plt.style.use('default')

#y값만 전달, x축은 자동으로 0,1,2,3이 설정됨
plt.plot([2,4,6,8])
plt.show()

# %%
x = [2,4,6,8,]
y = [1,3,5,7]
plt.plot(x,y)
plt.show()

# %%
x = range(11)
y = range(5,16)
plt.plot(x,y, 'ro')
plt.show()

#색상옵션, 마커옵션 있음

# %%
fig = plt.figure()
#(행개수, 열개수, 위치값)
fig.add_subplot(2,1,1)
fig.add_subplot(2,1,2)
plt.show()

# %%
fig = plt.figure()
#(행개수, 열개수, 위치값)
fig.add_subplot(1,2,1)
fig.add_subplot(1,2,2)
plt.show()

# %%
fig = plt.figure()
#(행개수, 열개수, 위치값)
fig.add_subplot(1,2,1)
fig.add_subplot(2,2,2)
plt.show()

# %%
fig = plt.figure()

a1 = fig.add_subplot(1,2,1)
a2 = fig.add_subplot(1,2,2)

x = range(0,10)
y = range(5,15)
a1.plot(x,y,"y^")

x = range(0,50)
y = range(0,50)
a2.plot(x,y,"k+")

plt.show()

# %%
import matplotlib
import matplotlib.font_manager as fm

#간격을 가능한 최적의 수치로 자동 조정
fig = plt.figure(constrained_layout=True)

#원하는 폰트 파일 경로 문자열로 입력
font_location = "C:\Windows\Fonts\H2GTRE.TTF"
#지정한 폰트 파일 경로에서 폰트 추출
fontname = fm.FontProperties(fname=font_location).get_name()
#matplotlib의 전역 폰트 설정 변경
matplotlib.rc('font', family = fontname)



a1 = fig.add_subplot(1,2,1)
a2 = fig.add_subplot(1,2,2)

x = range(0,10)
y = range(5,15)
a1.plot(x,y,"yo")

x = range(0,50)
y = range(0,50)
a2.plot(x,y,"kv")

#x축, y축 이름 지정
a1.set_xlabel('시간')
a1.set_ylabel('돈')

a2.set_xlabel('시간')
a2.set_ylabel('돈')

plt.show()
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\W'
# <>:8: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\admin\AppData\Local\Temp\ipykernel_4204\1437571494.py:8: SyntaxWarning: invalid escape sequence '\W'
#   font_location = "C:\Windows\Fonts\H2GTRE.TTF"

# %%
fig = plt.figure()

plt.style.use('ggplot')

a = fig.add_subplot(111)
x = [3,4] #막대의 위치(좌표 기준)
y = [1,2] #막대의 높이(값 기준)

# x축 라벨 이름(tick 이름)
labels = ['english', 'math']
#각 막대에 적용할 색상
colors = ['red', 'blue']


a.bar(x,y,tick_label=labels, color=colors)
plt.show()

# %%
fig = plt.figure()

plt.style.use('ggplot')

a = fig.add_subplot(111)
x = [3,4] #막대의 위치(좌표 기준)
y = [1,2] #막대의 높이(값 기준)

# x축 라벨 이름(tick 이름)
labels = ['english', 'math']
#각 막대에 적용할 색상
colors = ['red', 'blue']


a.barh(x,y,tick_label=labels, color=colors) #bar 뒤에 h붙이면 가로로 나옴
plt.show()

# %%
fig = plt.figure()

plt.style.use('ggplot')

a = fig.add_subplot(111)
x = [3,4] #막대의 위치(좌표 기준)
y = [1,2] #막대의 높이(값 기준)

# x축 라벨 이름(tick 이름)
labels = ['english', 'math']
#각 막대에 적용할 색상
colors = ['red', 'blue']


a.bar(x,y,tick_label=labels, color=colors)

for i, v in enumerate(y):
    a.text(v+2, i+1.05, str(v)) #표준 수치



plt.show()
